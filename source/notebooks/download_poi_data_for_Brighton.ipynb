# %% [markdown]
# # Download OpenStreetMap POI data for Brighton & Hove
#
# This tutorial shows how you can download Points of Interest (POI) data for Brighton and Hove from OpenStreetMap.

# %%
import osmnx as ox
import geopandas as gpd
from shapely.geometry import box

# %% [markdown]
# ### Define the area of interest
#
# Let's create a GeoDataFrame with Polygon that defines the area of interest for us. We will only collect data from this area.

# %%
# Data extent for Brighton
# minx, miny, maxx, maxy
bounds = (-0.49975, 50.73,  0.3469234, 50.98)

# Create a GeoDataFrame
gdf = gpd.GeoDataFrame(geometry=[box(*bounds)], crs="EPSG:4326")

# Plot to map
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f6fa60e44bf5a2f0816d1497d778efd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f6fa60e44bf5a2f0816d1497d778efd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f6fa60e44bf5a2f0816d1497d778efd = L.map(
#                 &quot;map_9f6fa60e44bf5a2f0816d1497d778efd&quot;,
#                 {
#                     center: [50.855, -0.07641330000000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9f6fa60e44bf5a2f0816d1497d778efd);
#
#
#
#
#
#             var tile_layer_cf1ecd98b1602a91ed7fa87ee146e28d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f6fa60e44bf5a2f0816d1497d778efd);
#
#
#             map_9f6fa60e44bf5a2f0816d1497d778efd.fitBounds(
#                 [[50.73, -0.49975], [50.98, 0.3469234]],
#                 {}
#             );
#
#
#         function geo_json_0382eab1941b165326da350505702a4a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0382eab1941b165326da350505702a4a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0382eab1941b165326da350505702a4a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0382eab1941b165326da350505702a4a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0382eab1941b165326da350505702a4a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0382eab1941b165326da350505702a4a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0382eab1941b165326da350505702a4a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0382eab1941b165326da350505702a4a = L.geoJson(null, {
#                 onEachFeature: geo_json_0382eab1941b165326da350505702a4a_onEachFeature,
#
#                 style: geo_json_0382eab1941b165326da350505702a4a_styler,
#                 pointToLayer: geo_json_0382eab1941b165326da350505702a4a_pointToLayer
#         });
#
#         function geo_json_0382eab1941b165326da350505702a4a_add (data) {
#             geo_json_0382eab1941b165326da350505702a4a
#                 .addData(data)
#                 .addTo(map_9f6fa60e44bf5a2f0816d1497d778efd);
#         }
#             geo_json_0382eab1941b165326da350505702a4a_add({&quot;bbox&quot;: [-0.49975, 50.73, 0.3469234, 50.98], &quot;features&quot;: [{&quot;bbox&quot;: [-0.49975, 50.73, 0.3469234, 50.98], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[0.3469234, 50.73], [0.3469234, 50.98], [-0.49975, 50.98], [-0.49975, 50.73], [0.3469234, 50.73]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_0382eab1941b165326da350505702a4a.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;);
#
#     return div
#     }
#     ,{&quot;className&quot;: &quot;foliumtooltip&quot;, &quot;sticky&quot;: true});
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:

# %% [markdown]
# ## Extract information about restaurants

# %%
# Download restaurants using Osmnx
tags = {"amenity": "restaurant"}
restaurants = ox.geometries_from_polygon(gdf.geometry.values[0], tags)

# Use centroid as geometry (we ignore the shape of the building)
restaurants["geometry"] = restaurants.centroid

# Plot to map
restaurants.explore()
# Out:
# /tmp/ipykernel_493210/3658294838.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   restaurants["geometry"] = restaurants.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f22c90346bcb3197728928467e68d07e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f22c90346bcb3197728928467e68d07e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f22c90346bcb3197728928467e68d07e = L.map(
#                 &quot;map_f22c90346bcb3197728928467e68d07e&quot;,
#                 {
#                     center: [50.856816560012966, -0.08076623055473578],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f22c90346bcb3197728928467e68d07e);
#
#
#
#
#
#             var tile_layer_8e770bd2dd728c6e81fd89d1ea6d39bf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f22c90346bcb3197728928467e68d07e);
#
#
#             map_f22c90346bcb3197728928467e68d07e.fitBounds(
#                 [[50.7402033, -0.49633856110947155], [50.973429820025935, 0.3348061]],
#                 {}
#             );
#
#
#         function geo_json_7caae3546ed0fbaf2d02ee4b26915f18_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_7caae3546ed0fbaf2d02ee4b26915f18_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_7caae3546ed0fbaf2d02ee4b26915f18_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_7caae3546ed0fbaf2d02ee4b26915f18_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_7caae3546ed0fbaf2d02ee4b26915f18_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_7caae3546ed0fbaf2d02ee4b26915f18.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_7caae3546ed0fbaf2d02ee4b26915f18_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_7caae3546ed0fbaf2d02ee4b26915f18 = L.geoJson(null, {
#                 onEachFeature: geo_json_7caae3546ed0fbaf2d02ee4b26915f18_onEachFeature,
#
#                 style: geo_json_7caae3546ed0fbaf2d02ee4b26915f18_styler,
#                 pointToLayer: geo_json_7caae3546ed0fbaf2d02ee4b26915f18_pointToLayer
#         });
#
#         function geo_json_7caae3546ed0fbaf2d02ee4b26915f18_add (data) {
#             geo_json_7caae3546ed0fbaf2d02ee4b26915f18
#                 .addData(data)
#                 .addTo(map_f22c90346bcb3197728928467e68d07e);
#         }
#             geo_json_7caae3546ed0fbaf2d02ee4b26915f18_add({&quot;bbox&quot;: [-0.49633856110947155, 50.7402033, 0.3348061, 50.973429820025935], &quot;features&quot;: [{&quot;bbox&quot;: [-0.1980875, 50.8526282, -0.1980875, 50.8526282], &quot;geometry&quot;: {&quot;coordinates&quot;: [-0.1980875, 50.8526282], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;(\u0027node\u0027, 27195055)&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: null, &quot;addr:country&quot;: null, &quot;addr:county&quot;: null, &quot;addr:floor&quot;: null, &quot;addr:housename&quot;: null, &quot;addr:housenumber&quot;: &quot;173&quot;, &quot;addr:locality&quot;: null, &quot;addr:parentstreet&quot;: null, &quot;addr:place&quot;: null, &quot;addr:postcode&quot;: &quot;BN3 8EY&quot;, &quot;addr:street&quot;: &quot;Hangleton Way&quo

# %% [markdown]
# ## Extract information about schools

# %%
# Download schools
tags = {"amenity": "school"}
schools = ox.geometries_from_polygon(gdf.geometry.values[0], tags)

# Use centroid as geometry (we ignore the shape of the building)
schools["geometry"] = schools.centroid

# Plot to map
schools.explore()
# Out:
# /tmp/ipykernel_493210/808073114.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   schools["geometry"] = schools.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6d5b2982f9671cb1936e2406b929958 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6d5b2982f9671cb1936e2406b929958&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6d5b2982f9671cb1936e2406b929958 = L.map(
#                 &quot;map_d6d5b2982f9671cb1936e2406b929958&quot;,
#                 {
#                     center: [50.863034648534736, -0.08568689441337829],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d6d5b2982f9671cb1936e2406b929958);
#
#
#
#
#
#             var tile_layer_8b0946e537afbe20d7c4402bb72a0d59 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6d5b2982f9671cb1936e2406b929958);
#
#
#             map_d6d5b2982f9671cb1936e2406b929958.fitBounds(
#                 [[50.751564058720724, -0.5002763236379008], [50.97450523834875, 0.3289025348111442]],
#                 {}
#             );
#
#
#         function geo_json_ab5fa8f46cd7116013e595a217aaba46_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ab5fa8f46cd7116013e595a217aaba46_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ab5fa8f46cd7116013e595a217aaba46_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ab5fa8f46cd7116013e595a217aaba46_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ab5fa8f46cd7116013e595a217aaba46_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_ab5fa8f46cd7116013e595a217aaba46.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ab5fa8f46cd7116013e595a217aaba46_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ab5fa8f46cd7116013e595a217aaba46 = L.geoJson(null, {
#                 onEachFeature: geo_json_ab5fa8f46cd7116013e595a217aaba46_onEachFeature,
#
#                 style: geo_json_ab5fa8f46cd7116013e595a217aaba46_styler,
#                 pointToLayer: geo_json_ab5fa8f46cd7116013e595a217aaba46_pointToLayer
#         });
#
#         function geo_json_ab5fa8f46cd7116013e595a217aaba46_add (data) {
#             geo_json_ab5fa8f46cd7116013e595a217aaba46
#                 .addData(data)
#                 .addTo(map_d6d5b2982f9671cb1936e2406b929958);
#         }
#             geo_json_ab5fa8f46cd7116013e595a217aaba46_add({&quot;bbox&quot;: [-0.5002763236379008, 50.751564058720724, 0.3289025348111442, 50.97450523834875], &quot;features&quot;: [{&quot;bbox&quot;: [-0.1373289, 50.8290457, -0.1373289, 50.8290457], &quot;geometry&quot;: {&quot;coordinates&quot;: [-0.1373289, 50.8290457], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;(\u0027node\u0027, 20945797)&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: null, &quot;addr:country&quot;: null, &quot;addr:housename&quot;: null, &quot;addr:housenumber&quot;: null, &quot;addr:locality&quot;: null, &quot;addr:place&quot;: null, &quot;addr:postcode&quot;: null, &quot;addr:province&quot;: null, &quot;addr:street&quot;: null, &quot;addr:suburb&quot;: null, &quot;age&quot;: null, &quot;alt_name&quot;: nu

# %% [markdown]
# ## Extract information about healthcare facilities

# %%
# Download schools
tags = {"amenity": ["clinic", "doctors", "hospital"]}
healthcare = ox.geometries_from_polygon(gdf.geometry.values[0], tags)

# Use centroid as geometry (we ignore the shape of the building)
healthcare["geometry"] = healthcare.centroid

# Plot to map
healthcare.explore()
# Out:
# /tmp/ipykernel_493210/1219259598.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   healthcare["geometry"] = healthcare.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c619b6147ee0809242023f32f7e1f58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c619b6147ee0809242023f32f7e1f58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c619b6147ee0809242023f32f7e1f58 = L.map(
#                 &quot;map_2c619b6147ee0809242023f32f7e1f58&quot;,
#                 {
#                     center: [50.86483072997905, -0.07656279999999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2c619b6147ee0809242023f32f7e1f58);
#
#
#
#
#
#             var tile_layer_9d67191fdf2e3960b2c4b68fdf0c1026 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c619b6147ee0809242023f32f7e1f58);
#
#
#             map_2c619b6147ee0809242023f32f7e1f58.fitBounds(
#                 [[50.755570075450656, -0.4910328], [50.97409138450744, 0.3379072]],
#                 {}
#             );
#
#
#         function geo_json_a0a66819deca43768a7ac090e8e8ccfb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a0a66819deca43768a7ac090e8e8ccfb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a0a66819deca43768a7ac090e8e8ccfb_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a0a66819deca43768a7ac090e8e8ccfb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a0a66819deca43768a7ac090e8e8ccfb_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a0a66819deca43768a7ac090e8e8ccfb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a0a66819deca43768a7ac090e8e8ccfb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a0a66819deca43768a7ac090e8e8ccfb = L.geoJson(null, {
#                 onEachFeature: geo_json_a0a66819deca43768a7ac090e8e8ccfb_onEachFeature,
#
#                 style: geo_json_a0a66819deca43768a7ac090e8e8ccfb_styler,
#                 pointToLayer: geo_json_a0a66819deca43768a7ac090e8e8ccfb_pointToLayer
#         });
#
#         function geo_json_a0a66819deca43768a7ac090e8e8ccfb_add (data) {
#             geo_json_a0a66819deca43768a7ac090e8e8ccfb
#                 .addData(data)
#                 .addTo(map_2c619b6147ee0809242023f32f7e1f58);
#         }
#             geo_json_a0a66819deca43768a7ac090e8e8ccfb_add({&quot;bbox&quot;: [-0.4910328, 50.755570075450656, 0.3379072, 50.97409138450744], &quot;features&quot;: [{&quot;bbox&quot;: [-0.1842301, 50.8301875, -0.1842301, 50.8301875], &quot;geometry&quot;: {&quot;coordinates&quot;: [-0.1842301, 50.8301875], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;(\u0027node\u0027, 25330284)&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: null, &quot;addr:hamlet&quot;: null, &quot;addr:housename&quot;: null, &quot;addr:housenumber&quot;: null, &quot;addr:locality&quot;: null, &quot;addr:parentstreet&quot;: null, &quot;addr:postcode&quot;: null, &quot;addr:street&quot;: null, &quot;addr:village&quot;: null, &quot;alt_name&quot;: null, &quot;amenity&quot;: &quot;hospital&quot;, &quot;area&quot;: null, &quot;building&

# %% [markdown]
# ## Save data to disk

# %% [markdown]
# ### Restaurants

# %%
# GeoDataFrame has MultiLevel index - We only want to keep the second one and drop the first 
restaurants["id"] = restaurants.index.droplevel(level=0)

# Restaurants (store only specific columns)
restaurants[["id", "name", "geometry"]].to_file("data/Brighton/Brighton_restaurants.gpkg")

# %% [markdown]
# ### Schools

# %%
# GeoDataFrame has MultiLevel index - We only want to keep the second one and drop the first 
schools["id"] = schools.index.droplevel(level=0)

# Restaurants (store only specific columns)
schools[["id", "name", "geometry"]].to_file("data/Brighton/Brighton_schools.gpkg")

# %% [markdown]
# ### Healthcare facilities

# %%
# GeoDataFrame has MultiLevel index - We only want to keep the second one and drop the first 
healthcare["id"] = healthcare.index.droplevel(level=0)

# Restaurants (store only specific columns)
healthcare[["id", "name", "geometry"]].to_file("data/Brighton/Brighton_healthcare.gpkg")
